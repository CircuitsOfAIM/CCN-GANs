# %% [markdown]
# ### Generating game character with generative adversarial networks
#
# Training a generative adversarial network on the  0x72.itch.io-scraped dataset of 185472 16 × 16 pixel 2-bit gameboy-character-like images to generate characters.

# %%
import random
from typing import Tuple
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from PIL import Image
from torchvision.transforms import ToPILImage
from torch.utils.data import Dataset, DataLoader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 from typing import Tuple
#       4 import numpy as np
# ----> 5 import torch
#       6 import torch.nn as nn
#       7 import torch.optim as optim
#
# ModuleNotFoundError: No module named 'torch'

# %%
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
gbc_ndarray = np.load("./gbc_dataset.npy")

class GBCDataset(Dataset):
    """
    Implement gameboy character dataset (GBCDataset) class.

    Attributes:
        dat (np.ndarray): Data.
        dev (str): Device.
    """
    def __init__(self, data, device):
        """
        Instantiate GBCDataset class.

        Args:
            data (np.ndarray): Data.
            device (str): Device.
        """
        self.dat = data
        self.dev = device

    def __len__(self):
        """
        Get dataset cardinality.

        Returns:
            int: Dataset cardinality.
        """
        return self.dat.shape[0]

    def __getitem__(self, index):
        """
        Get dataset element.

        Args:
            index (int): Index.

        Returns:
            torch.Tensor: Dataset element.
        """
        return torch.from_numpy(self.dat[index].astype(np.float32) / 127.5 - 1.0).to(self.dev)

gbc_dataset = GBCDataset(gbc_ndarray,device)
gbc_data_loader = DataLoader(gbc_dataset, 42, True)
# Out:
# --2023-05-24 17:10:05--  https://umuguc.github.io/file-sharing/gbc_dataset.npy.zip
#
# Resolving umuguc.github.io (umuguc.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
#
# Connecting to umuguc.github.io (umuguc.github.io)|185.199.108.153|:443... connected.
#
# HTTP request sent, awaiting response... 200 OK
#
# Length: 925054 (903K) [application/zip]
#
# Saving to: ‘gbc_dataset.npy.zip’
#
#
#
# gbc_dataset.npy.zip 100%[===================>] 903.37K  --.-KB/s    in 0.006s
#
#
#
# 2023-05-24 17:10:05 (138 MB/s) - ‘gbc_dataset.npy.zip’ saved [925054/925054]
#
#
#
# Archive:  gbc_dataset.npy.zip
#
#   inflating: assignment_5/gbc_dataset.npy
#
#   inflating: assignment_5/__MACOSX/._gbc_dataset.npy

# %%
class GBCGAN:
    """
    Implement gameboy character generative adversarial network (GBCGAN) class.

    Attributes:
        _dis_net (nn.Sequential): Discriminator network.
        _dis_opt (optim.Optimizer): Discriminator optimiser.
        _gen_net (nn.Sequential): Generator network.
        _gen_opt (optim.Optimizer): Generator optimiser.
        _lat_dim (int): Latent dimensionality.
        _los_fun (nn.Loss): Loss function.
        dev (str): Device.

    Methods:
        _get_discriminator(): Get discriminator network and discriminator optimiser.
        _get_generator(): Get generator network and generator optimiser.
        generate_images(batch_size): Generate fake images.
        train_networks(dataset, epoch_num, batch_size): Train discriminator network and generator network.
    """

    def __init__(self, device: str = "cuda") -> None:
        """
        Instantiate GBCGAN class.

        Args:
            device (str): Device.
        """
        self.dev = device
        self._dis_net, self._dis_opt = self._get_discriminator()
        self._gen_net, self._gen_opt = self._get_generator()
        self._lat_dim = self._gen_net[0].in_channels
        self._los_fun = nn.BCELoss()

    def _get_discriminator(self) -> Tuple[nn.Sequential, optim.Optimizer]:
        """
        Get discriminator network and discriminator optimiser.

        Returns:
            network (nn.Sequential): Discriminator network.
            optimiser (optim.Optimizer): Discriminator optimiser.
        """
        network = nn.Sequential(
            nn.Conv2d(1,16,kernel_size=4, stride=2, padding=1,bias=False),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(negative_slope=0.2),
            nn.Conv2d(16,32,kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(negative_slope=0.2),
            nn.Conv2d(32,1,kernel_size=4, stride=1, padding=1, bias=False),
            nn.Sigmoid()
        ).to(self.dev)
        
        optimiser = optim.Adam(network.parameters(), lr=0.0002, betas=(0.5, 0.999))

        return network, optimiser

    def _get_generator(self) -> Tuple[nn.Sequential, optim.Optimizer]:
        """
        Get generator network and generator optimiser.

        Returns:
            network (nn.Sequential): Generator network.
            optimiser (optim.Optimizer): Generator optimiser.
        """
        
        network = nn.Sequential(
            nn.ConvTranspose2d(64,32,kernel_size=4, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.ConvTranspose2d(32,16,kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.ConvTranspose2d(16,1,kernel_size=4, stride=2, padding=1, bias=False),
            nn.Tanh()
        ).to(self.dev)

        optimiser = optim.Adam(network.parameters(), lr=0.0002, betas=(0.5, 0.999))

        return network, optimiser

    def generate_images(self, batch_size):
        """
        Generate fake images.

        Args:
            batch_size (int): Batch size.

        Returns:
            fake_images (PIL.Image): Fake images.
        """
        random_latents = torch.randn(batch_size, self._lat_dim,1,1, device=self.dev)
        temp_images = self._gen_net(random_latents)
        to_pil = ToPILImage()

        fake_images = []

        for i in range(batch_size):
            fake_image = to_pil(temp_images[i].cpu().detach())
            fake_images.append(fake_image)

        final_image = Image.new("L", (16 * batch_size, 16))

        for i, image in enumerate(fake_images):
            final_image.paste(image, (16 * i, 0))

        return final_image

    def train_networks(self, gbc_data_loader: DataLoader, epoch_number: int=1) -> None:
        """
        Train discriminator network and generator network.

        Args:
            gbc_data_loader (DataLoader): GBC data loader.
            epoch_number (int): Epochs number.
        """
        self._dis_net.train()
        self._gen_net.train()
        for epoch in range(epoch_number):
            discriminator_losses = []
            generator_losses = []

            for real_images in gbc_data_loader:

                random_latents =torch.randn(real_images.shape[0], self._lat_dim,1,1, device=self.dev)
                fake_images = self._gen_net(random_latents)
                fake_probs =self._dis_net(fake_images)
                fake_labels =torch.zeros(fake_probs.shape)
                
                real_probs =self._dis_net(real_images)
                real_labels =torch.ones(real_probs.shape)

                discriminator_loss = self._los_fun(fake_probs,fake_labels)+self._los_fun(real_probs,real_labels)
                self._dis_opt.zero_grad()
                discriminator_loss.backward()
                self._dis_opt.step()

                discriminator_losses.append(discriminator_loss.item())

                random_latents =torch.randn(real_images.shape[0], self._lat_dim,1,1, device=self.dev)
                fake_images =self._gen_net(random_latents)
                fake_probs =self._dis_net(fake_images)
                real_labels =torch.ones_like(fake_probs)

                generator_loss =self._los_fun(fake_probs, real_labels)
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0301
#
# Generator loss: 9.7030
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0301
#
# Generator loss: 9.7029
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0301
#
# Generator loss: 9.7032
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0301
#
# Generator loss: 9.7031
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0301
#
# Generator loss: 9.7033
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0301
#
# Generator loss: 9.7032
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0301
#
# Generator loss: 9.7032
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0301
#
# Generator loss: 9.7029
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0301
#
# Generator loss: 9.7030
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0301
#
# Generator loss: 9.7029
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0301
#
# Generator loss: 9.7025
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0300
#
# Generator loss: 9.7026
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0300
#
# Generator loss: 9.7026
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0300
#
# Generator loss: 9.7025
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0300
#
# Generator loss: 9.7028
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0300
#
# Generator loss: 9.7030
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0300
#
# Generator loss: 9.7032
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0300
#
# Generator loss: 9.7033
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0300
#
# Generator loss: 9.7039
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0300
#
# Generator loss: 9.7040
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0300
#
# Generator loss: 9.7032
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0301
#
# Generator loss: 9.7039
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0301
#
# Generator loss: 9.7035
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0302
#
# Generator loss: 9.7022
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0305
#
# Generator loss: 9.7037
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0310
#
# Generator loss: 9.7023
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0315
#
# Generator loss: 9.7024
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0316
#
# Generator loss: 9.7029
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0322
#
# Generator loss: 9.7011
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0338
#
# Generator loss: 9.7004
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0342
#
# Generator loss: 9.7013
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0346
#
# Generator loss: 9.7016
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0346
#
# Generator loss: 9.7010
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0347
#
# Generator loss: 9.7000
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0348
#
# Generator loss: 9.6995
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0348
#
# Generator loss: 9.6997
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0348
#
# Generator loss: 9.6993
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0349
#
# Generator loss: 9.6983
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0349
#
# Generator loss: 9.6972
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0349
#
# Generator loss: 9.6961
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0350
#
# Generator loss: 9.6957
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0350
#
# Generator loss: 9.6952
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0350
#
# Generator loss: 9.6952
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0350
#
# Generator loss: 9.6947
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0350
#
# Generator loss: 9.6940
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6935
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6929
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6924
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6919
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6914
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6907
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6902
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6896
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6893
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6888
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6884
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6878
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6873
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6871
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6868
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6864
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6862
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6860
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6857
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6857
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6855
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6855
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6850
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6848
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6845
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6839
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6836
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6829
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6827
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6824
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6818
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6815
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6813
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6806
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6800
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6799
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6792
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6791
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6785
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6781
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6777
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6773
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6768
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6766
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6765
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6760
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6756
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6752
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6748
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6749
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6745
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6742
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6742
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6739
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6736
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6734
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6730
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6728
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6726
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6728
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6726
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6726
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6723
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6721
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6719
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6714
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6712
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6710
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6711
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6709
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6706
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6702
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6702
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6699
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6700
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6702
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6698
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6695
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6690
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6687
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6686
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6682
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6682
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6676
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6674
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6673
#
# Epoch: [10/10]
#
# Discriminator loss: 0.0351
#
# Generator loss: 9.6672

# %%
fake_images = gbcgan.generate_images(42)

fake_images.show()
fake_images.save("./fake_images.png")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in fromarray(obj, mode)
#    2834         try:
# -> 2835             mode, rawmode = _fromarray_typemap[typekey]
#    2836         except KeyError as e:
#
# KeyError: ((1, 1, 1), '|u1')
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-1c769a0e3fb2> in <cell line: 1>()
# ----> 1 fake_images = gbcgan.generate_images(42) # You can change the argument to change the batch size.
#       2
#       3 fake_images.show()
#       4 fake_images.save("assignment_5/fake_images.png") # You can change the argument to change the path as long as the directory exists.
#
# <ipython-input-102-445a2ea96472> in generate_images(self, batch_size)
#     129
#     130         for i in range(batch_size):
# --> 131             fake_images.paste(Image.fromarray((127.5 * (temp_images[i].detach().cpu().numpy().transpose(1, 2, 0) + 1.0)).astype(np.uint8)), (16 * i, 0))
#     132
#     133         return fake_images
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in fromarray(obj, mode)
#    2835             mode, rawmode = _fromarray_typemap[typekey]
#    2836         except KeyError as e:
# -> 2837             raise TypeError("Cannot handle this data type: %s, %s" % typekey) from e
#    2838     else:
#    2839         rawmode = mode
#
# TypeError: Cannot handle this data type: (1, 1, 1), |u1
